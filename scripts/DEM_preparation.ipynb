# %% [markdown]
# # DEMs handling for Where The Water Flows Subglacially #

# %%
import pyproj
import xdem
# Out:
# ERROR 1: PROJ: proj_create_from_database: Cannot find proj.db
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File rasterio/crs.pyx:592, in rasterio.crs.CRS.from_epsg()
#
# File rasterio/_err.pyx:289, in rasterio._err.exc_wrap_int()
#
# CPLE_AppDefinedError: PROJ: proj_create_from_database: Cannot find proj.db
#
# During handling of the above exception, another exception occurred:
#
# CRSError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pyproj
# ----> 2 import xdem
#
# File /scratch-1/cogier/xdem/xdem/__init__.py:19
#       1 # Copyright (c) 2024 xDEM developers
#       2 #
#       3 # This file is part of the xDEM project:
#    (...)
#      16 # See the License for the specific language governing permissions and
#      17 # limitations under the License.
# ---> 19 from xdem import (  # noqa
#      20     coreg,
# ...

# %%
pyproj.__version__
# Out:
# '3.7.1'
